# %%
import json
import ifcopenshell
import ifcHelper 
import pandas as pd
import numpy as np
import lcabygjson as lcabygjson
import uuid

# %%
file_name =  'exceldata.xls'

# %%
sheet_konstruktioner =  'Konstruktioner' # sheet name or sheet number or list of sheet numbers and names

try:
  konstruktioner_df = pd.read_excel(io=file_name, sheet_name=sheet_konstruktioner)
  print("Konstruktioner Excel File loaded successfully")
  print(konstruktioner_df.head(2))  # print first 5 rows of the dataframe
except:
  print("An exception occurred")
# Out:
# Konstruktioner Excel File loaded successfully
#                    Row Labels  Sum of Area            Lot  ProductAmount Unit  \
# 0  (12)1 Sokkel under ydervæg       138.45  21. YDERVÆGGE              1   M2
# 1     (21)1 - Ydervæg, Kælder       603.01  21. YDERVÆGGE              1   M2
#
#                                               Layers
# 0            BA - f0 - Puds 10_Bips - Polystyren 250
# 1  By Category 10_Bips - Beton Element 250_Bips -...

# %%
sheet_products =  'Products' # sheet name or sheet number or list of sheet numbers and names

try:
  products_df = pd.read_excel(io=file_name, sheet_name=sheet_products)
  print("Products Excel File loaded successfully")
  print(products_df.head(2))  # print first 5 rows of the dataframe
except:
  print("An exception occurred")
# Out:
# Products Excel File loaded successfully
#        Row Labels     EnglishName      RevitNames     Polish name  \
# 0  Testproduct m2  Testproduct m2  Testproduct m2  Testproduct m2
# 1   Testproduct m   Testproduct m   Testproduct m   Testproduct m
#
#          LCABYGmaterial  Amount Unit                             Productid  \
# 0  Kalksandsten (A1-A3)       1   M3  51bcec85-9105-4946-8a8a-51219bf9adfa
# 1  Kalksandsten (A1-A3)       1   M2  5dcafff0-1ec7-49e7-b425-fff6d1a0e03f
#
#                          ProductToStage                                  A1A3  \
# 0  61a77bc8-bddb-4521-9862-e613e26a5661  e60d6a55-44e3-5ade-88f5-07e0fd29d1d0
# 1  e85a401f-2cb7-4de5-a3a2-ac222cfad9ef  e60d6a55-44e3-5ade-88f5-07e0fd29d1d0
#
#                                      C3   C4  \
# 0  caa5e6c3-0efd-53b6-8b9b-2142880cc69f  XXX
# 1  caa5e6c3-0efd-53b6-8b9b-2142880cc69f  XXX
#
#                                       D
# 0  9a4ebb4a-f90a-5e0b-b5b5-76b0a965c1f0
# 1  9a4ebb4a-f90a-5e0b-b5b5-76b0a965c1f0

# %%
sheet_other =  'Andet' # sheet name or sheet number or list of sheet numbers and names

try:
  other_df = pd.read_excel(io=file_name, sheet_name=sheet_other)
  print("Other Excel File loaded successfully")
  print(other_df.head(2))  # print first 5 rows of the dataframe
except:
  print("An exception occurred")
# Out:
# Other Excel File loaded successfully
# Empty DataFrame
# Columns: []
# Index: []

# %%
json_array_elements = []
json_array_constructions = []
json_array_element_category_edges = []
json_array_constructions_extra = []

# %%
konstruktioner_df_L12 = konstruktioner_df[konstruktioner_df['Lot'] == '12. FUNDAMENTER'].reset_index()
konstruktioner_df_L13 = konstruktioner_df[konstruktioner_df['Lot'] == '13. TERRÆNDÆK'].reset_index()
konstruktioner_df_L21 = konstruktioner_df[konstruktioner_df['Lot'] == '21. YDERVÆGGE'].reset_index()
konstruktioner_df_L22 = konstruktioner_df[konstruktioner_df['Lot'] == '22. INDERVÆGGE'].reset_index()
konstruktioner_df_L23 = konstruktioner_df[konstruktioner_df['Lot'] == '23. ETAGEDÆK'].reset_index()
konstruktioner_df_L27 = konstruktioner_df[konstruktioner_df['Lot'] == '27. TAGE'].reset_index()
konstruktioner_df_L31 = konstruktioner_df[konstruktioner_df['Lot'] == '31. YDERVÆGGE, KOMPLETTERING'].reset_index()
konstruktioner_df_L43 = konstruktioner_df[konstruktioner_df['Lot'] == '43. GULVE'].reset_index()
konstruktioner_df_L45 = konstruktioner_df[konstruktioner_df['Lot'] == '45. LOFTER'].reset_index()

# %%
other_df_L12 = other_df[other_df['Lot'] == '12. FUNDAMENTER'].reset_index()
other_df_L13 = other_df[other_df['Lot'] == '13. TERRÆNDÆK'].reset_index()
other_df_L21 = other_df[other_df['Lot'] == '21. YDERVÆGGE'].reset_index()
other_df_L22 = other_df[other_df['Lot'] == '22. INDERVÆGGE'].reset_index()
other_df_L23 = other_df[other_df['Lot'] == '23. ETAGEDÆK'].reset_index()
other_df_L27 = other_df[other_df['Lot'] == '27. TAGE'].reset_index()
other_df_L31 = other_df[other_df['Lot'] == '31. YDERVÆGGE, KOMPLETTERING'].reset_index()
other_df_L43 = other_df[other_df['Lot'] == '43. GULVE'].reset_index()
other_df_L45 = other_df[other_df['Lot'] == '45. LOFTER'].reset_index()

# %%
L12_conc = [konstruktioner_df_L12,other_df_L12]
L13_conc = [konstruktioner_df_L13,other_df_L13]
L21_conc = [konstruktioner_df_L21,other_df_L21]
L22_conc = [konstruktioner_df_L22,other_df_L22]
L23_conc = [konstruktioner_df_L23,other_df_L23]
L27_conc = [konstruktioner_df_L27,other_df_L27]
L31_conc = [konstruktioner_df_L31,other_df_L31]
L43_conc = [konstruktioner_df_L43,other_df_L43]
L45_conc = [konstruktioner_df_L45,other_df_L45]

# %%
L12 = pd.concat(L12_conc).reset_index()
L13 = pd.concat(L13_conc).reset_index()
L21 = pd.concat(L21_conc).reset_index()
L22 = pd.concat(L22_conc).reset_index()
L23 = pd.concat(L23_conc).reset_index()
L27 = pd.concat(L27_conc).reset_index()
L31 = pd.concat(L31_conc).reset_index()
L43 = pd.concat(L43_conc).reset_index()
L45 = pd.concat(L45_conc).reset_index()

# %%
L22
# Out:
#     level_0 index                              Row Labels  Sum of Area  \
# 0         0     8          (21)X - Ydervæg, Elevatorgrube        12.25
# 1         1     9                (22)1 - Lette indervægge      1347.37
# 2         2    10                     (22)10 - Skunkvægge       178.67
# 3         3    11  (22)12 - Tung skillevæg - 250 mm beton        43.66
# 4         4    12                     (22)13 - Loftskjørt       187.20
# 5         5    13        (22)13 - Loftskjørt (1 lag gips)        14.59
# 6         6    14                (22)2 - Lette Indervægge        94.69
# 7         7    15       (22)3 - Lette indervægge - Vådrum      2050.86
# 8         8    16                    (22)4 - Forsatsvægge       210.42
# 9         9    17             (22)5 - Forsatsvægge vådrum       804.97
# 10       10    18   (22)6 - Tung skillevæg - 200 mm beton       695.57
# 11       11    19                    (22)6 Lejlighedsskel      2001.96
# 12       12    20   (22)8 - Tung skillevæg - 180 mm beton      3933.06
#
#                Lot  ProductAmount Unit  \
# 0   22. INDERVÆGGE            1.0   M2
# 1   22. INDERVÆGGE            1.0   M2
# 2   22. INDERVÆGGE            1.0   M2
# 3   22. INDERVÆGGE            1.0   M2
# 4   22. INDERVÆGGE            1.0   M2
# 5   22. INDERVÆGGE            1.0   M2
# 6   22. INDERVÆGGE            1.0   M2
# 7   22. INDERVÆGGE            1.0   M2
# 8   22. INDERVÆGGE            1.0   M2
# 9   22. INDERVÆGGE            1.0   M2
# 10  22. INDERVÆGGE            1.0   M2
# 11  22. INDERVÆGGE            1.0   M2
# 12  22. INDERVÆGGE            1.0   M2
#
#                                                Layers Assumption Coefficient  \
# 0   By Category 10_Bips - Beton Element 180_Bips -...        NaN         NaN
# 1              Bips - Isolering Blød kl 34 95_Gips 13        NaN         NaN
# 2                              By Category 70_Gips 13        NaN         NaN
# 3                            Bips - Beton Element 250        NaN         NaN
# 4                              By Category 70_Gips 13        NaN         NaN
# 5              Bips - Isolering Blød kl 34 50_Gips 13        NaN         NaN
# 6              Bips - Isolering Blød kl 34 70_Gips 13        NaN         NaN
# 7              Bips - Isolering Blød kl 34 95_Gips 13        NaN         NaN
# 8              Bips - Isolering Blød kl 34 70_Gips 13        NaN         NaN
# 9              Bips - Isolering Blød kl 34 70_Gips 13        NaN         NaN
# 10                           Bips - Beton Element 200        NaN         NaN
# 11  By Category 10_Bips - Isolering Blød kl 34 70_...        NaN         NaN
# 12                           Bips - Beton Element 180        NaN         NaN
#
#    Multiplier
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN

# %%
lcabyg_elements = lcabygjson.create_lcabyg_elements()

# %%
lcabyg_elements
# Out:
# ([], [], [], [])

# %%
# L12 
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L12['Sum of Area'],L12['Row Labels'], '12. FUNDAMENTER',  L12['Unit'], L12['Layers'], products_df, '02c3e303-a443-4f02-9927-e43519227ade')
# Out:
# Added element:
# 12. FUNDAMENTER

# %%
# L13
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L13['Sum of Area'],L13['Row Labels'], '13. TERRÆNDÆK',  L13['Unit'], L13['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 13. TERRÆNDÆK
# Added construction
# (13)1 - Terrændæk, Kælderplan
# 633.0
# Layers:
# ['BA - f2 - Beton-Insitu 120', 'Bips - Polystyren 300']
# BA - f2 - Beton-Insitu 120
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 120
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.12
# Bips - Polystyren 300
# Products:
# Bips - Polystyren
# Amount from layer:
# 300
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.3
# Added construction
# (13)2 - Terrændæk, Kælderplan - Vådrum
# 147.0
# Layers:
# ['BA - f2 - Beton-Insitu 105', 'Bips - Polystyren 300']
# BA - f2 - Beton-Insitu 105
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 105
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.105
# Bips - Polystyren 300
# Products:
# Bips - Polystyren
# Amount from layer:
# 300
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.3
# Added construction
# (13)3 - Terrændæk Stueplan
# 2139.0
# Layers:
# ['BA - f2 - Beton-Insitu 120', 'Bips - Polystyren 300']
# BA - f2 - Beton-Insitu 120
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 120
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.12
# Bips - Polystyren 300
# Products:
# Bips - Polystyren
# Amount from layer:
# 300
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.3
# Added construction
# (13)4 - Terrændæk Stueplan - Vådrum
# 114.0
# Layers:
# ['BA - f2 - Beton-Insitu 120', 'Bips - Polystyren 300']
# BA - f2 - Beton-Insitu 120
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 120
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.12
# Bips - Polystyren 300
# Products:
# Bips - Polystyren
# Amount from layer:
# 300
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.3

# %% [raw]
# 12. FUNDAMENTER
#
# 13. TERRÆNDÆK
#
# 21. YDERVÆGGE
#
# 22. INDERVÆGGE
#
# 23. ETAGEDÆK
#
# 27. TAGE
#
# 31. YDERVÆGGE, KOMPLETTERING
#
# 43. GULVE
#
# 45. LOFTER

# %%
# L21
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L21['Sum of Area'],L21['Row Labels'], '21. YDERVÆGGE',  L21['Unit'], L21['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 21. YDERVÆGGE
# Added construction
# (12)1 Sokkel under ydervæg
# 138.45
# Layers:
# ['BA - f0 - Puds 10', 'Bips - Polystyren 250']
# BA - f0 - Puds 10
# Products:
# BA - f0 - Puds
# Amount from layer:
# 10
# M3
# Productid:
# 28b79b9f-ee4a-4c8e-843c-8f666713aca1
# LCABYG Name:
# Puds
# Final amount:
# 0.01
# Bips - Polystyren 250
# Products:
# Bips - Polystyren
# Amount from layer:
# 250
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.25
# Added construction
# (21)1 - Ydervæg, Kælder
# 603.01
# Layers:
# ['By Category 10', 'Bips - Beton Element 250', 'Bips - Polystyren 250']
# By Category 10
# Products:
# By Category
# Amount from layer:
# 10
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.01
# Bips - Beton Element 250
# Products:
# Bips - Beton Element
# Amount from layer:
# 250
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.25
# Bips - Polystyren 250
# Products:
# Bips - Polystyren
# Amount from layer:
# 250
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.25
# Added construction
# (21)2 - Ydervæg
# 2368.729999999999
# Layers:
# ['BA - f0 - Puds 10', 'Bips - Beton Element 180', 'Bips - Isolering Blød kl 34 250']
# BA - f0 - Puds 10
# Products:
# BA - f0 - Puds
# Amount from layer:
# 10
# M3
# Productid:
# 28b79b9f-ee4a-4c8e-843c-8f666713aca1
# LCABYG Name:
# Puds
# Final amount:
# 0.01
# Bips - Beton Element 180
# Products:
# Bips - Beton Element
# Amount from layer:
# 180
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.18
# Bips - Isolering Blød kl 34 250
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 250
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.25
# Added construction
# (21)3 - Kvist ydervægge
# 412.1900000000002
# Layers:
# ['By Category 6', 'By Category 9', 'By Category 25', 'Bips - Isolering Blød kl 34 45', 'Bips - Isolering Blød kl 34 195', 'Gips 13']
# By Category 6
# Products:
# By Category
# Amount from layer:
# 6
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.006
# By Category 9
# Products:
# By Category
# Amount from layer:
# 9
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.009
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Isolering Blød kl 34 45
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 45
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.045
# Bips - Isolering Blød kl 34 195
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 195
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.195
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (21)3 - Kvist ydervægge 2
# 1.56
# Layers:
# ['By Category 6', 'By Category 9', 'By Category 25', 'Bips - Isolering Blød kl 34 45', 'Bips - Isolering Blød kl 34 195', 'Gips 13']
# By Category 6
# Products:
# By Category
# Amount from layer:
# 6
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.006
# By Category 9
# Products:
# By Category
# Amount from layer:
# 9
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.009
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Isolering Blød kl 34 45
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 45
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.045
# Bips - Isolering Blød kl 34 195
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 195
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.195
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (21)4
# 35.129999999999995
# Layers:
# ['BA - f0 - Puds 10', 'Bips - Beton Element 150', 'Bips - Isolering Blød kl 34 250']
# BA - f0 - Puds 10
# Products:
# BA - f0 - Puds
# Amount from layer:
# 10
# M3
# Productid:
# 28b79b9f-ee4a-4c8e-843c-8f666713aca1
# LCABYG Name:
# Puds
# Final amount:
# 0.01
# Bips - Beton Element 150
# Products:
# Bips - Beton Element
# Amount from layer:
# 150
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.15
# Bips - Isolering Blød kl 34 250
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 250
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.25
# Added construction
# (21)4 2
# 4.54
# Layers:
# ['BA - f0 - Puds 10', 'Bips - Beton Element 150', 'Bips - Isolering Blød kl 34 250']
# BA - f0 - Puds 10
# Products:
# BA - f0 - Puds
# Amount from layer:
# 10
# M3
# Productid:
# 28b79b9f-ee4a-4c8e-843c-8f666713aca1
# LCABYG Name:
# Puds
# Final amount:
# 0.01
# Bips - Beton Element 150
# Products:
# Bips - Beton Element
# Amount from layer:
# 150
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.15
# Bips - Isolering Blød kl 34 250
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 250
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.25
# Added construction
# (21)4 Let ydervæg
# 42.0
# Layers:
# ['By Category 10', 'By Category 13', 'By Category 15', 'By Category 25', 'Bips - Isolering Blød kl 34 95', 'Bips - Isolering Blød kl 34 245', 'Gips 15']
# By Category 10
# Products:
# By Category
# Amount from layer:
# 10
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.01
# By Category 13
# Products:
# By Category
# Amount from layer:
# 13
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.013
# By Category 15
# Products:
# By Category
# Amount from layer:
# 15
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.015
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Isolering Blød kl 34 95
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 95
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.095
# Bips - Isolering Blød kl 34 245
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 245
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.245
# Gips 15
# Products:
# Gips
# Amount from layer:
# 15
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.015
# Added construction
# IVP-01.N01
# 5.02
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-01.N02
# 5.08
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-02 Curtain Wall
# 7.5
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-03 Curtain Wall
# 15.12
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-04 Nr.01
# 5.24
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-04 Nr.01 3
# 5.24
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-04 Nr.02
# 5.24
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-05 Curtain Wall
# 5.7
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-06 Curtain Wall
# 7.18
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-07 Curtain Wall
# 5.13
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-08 nr.01
# 5.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-08 nr.02
# 5.88
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-09 Curtain Wall
# 13.43
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-10 Curtain Wall
# 10.54
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-11 Curtain Wall
# 8.09
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-12 Curtain Wall
# 6.39
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-13 Curtain Wall
# 15.61
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# IVP-14
# 5.65
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.01
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.02
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.03
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.04
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.05
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.06
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.07
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.08
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.09
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.10
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.11
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.12
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.13
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.14
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.15
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.16
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.17
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.18
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.19
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.20
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.21
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.22
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.23
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.24
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.25
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.26
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.27
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.28
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.29
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.30
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.31
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.32
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.33
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.34
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.35
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.36
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.37
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.38
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.39
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-01.N.40
# 8.75
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.01
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.02
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.03
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.04
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.05
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.06
# 5.88
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.07
# 5.88
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-02.N.08
# 5.93
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-03.N.01
# 2.96
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-04.N.01
# 20.06
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-04.N.02
# 20.06
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-05.N.01
# 13.43
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-06.N.01
# 16.51
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-07.N.01
# 12.81
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.01
# 4.21
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.02
# 8.42
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.03
# 4.21
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.04
# 4.21
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.05
# 4.21
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-08.N.06
# 4.21
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-09.N.01
# 4.68
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-10.N.01
# 5.85
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-10.N.02
# 5.85
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-11.N.01
# 6.25
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-12.N.01
# 2.37
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-13.N.01
# 6.51
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-14.N.01
# 8.64
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-15.N.01
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-15.N.02
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-15.N.03
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-15.N.04
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.01
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.02
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.03
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.04
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.05
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-16.N.06
# 8.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-17.N.01
# 4.37
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-17.N.02
# 4.37
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-17.N.03
# 4.37
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-18.N.01
# 5.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-18.N.02
# 5.76
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# UVP-20.N.01
# 14.15
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# x Kølerums leverence
# 103.56
# Layers:
# ['Maling Hvid Mat 100']
# Maling Hvid Mat 100
# Products:
# Maling Hvid Mat
# Amount from layer:
# 100
# KG
# Productid:
# 1cde6c1c-7b19-454d-93b2-c8b1225f58a9
# LCABYG Name:
# Maling Hvid Mat
# Final amount:
# 0.1
# Added construction
# x Kølerums leverence 120
# 154.54000000000002
# Layers:
# ['Maling Hvid Mat 120']
# Maling Hvid Mat 120
# Products:
# Maling Hvid Mat
# Amount from layer:
# 120
# KG
# Productid:
# 1cde6c1c-7b19-454d-93b2-c8b1225f58a9
# LCABYG Name:
# Maling Hvid Mat
# Final amount:
# 0.12

# %%
# L22
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L22['Sum of Area'],L22['Row Labels'], '22. INDERVÆGGE',  L22['Unit'], L22['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 22. INDERVÆGGE
# Added construction
# (21)X - Ydervæg, Elevatorgrube
# 12.250000000000002
# Layers:
# ['By Category 10', 'Bips - Beton Element 180', 'Bips - Polystyren 230']
# By Category 10
# Products:
# By Category
# Amount from layer:
# 10
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.01
# Bips - Beton Element 180
# Products:
# Bips - Beton Element
# Amount from layer:
# 180
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.18
# Bips - Polystyren 230
# Products:
# Bips - Polystyren
# Amount from layer:
# 230
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.23
# Added construction
# (22)1 - Lette indervægge
# 1347.3700000000003
# Layers:
# ['Bips - Isolering Blød kl 34 95', 'Gips 13']
# Bips - Isolering Blød kl 34 95
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 95
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.095
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)10 - Skunkvægge
# 178.66999999999987
# Layers:
# ['By Category 70', 'Gips 13']
# By Category 70
# Products:
# By Category
# Amount from layer:
# 70
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)12 - Tung skillevæg - 250 mm beton
# 43.66
# Layers:
# ['Bips - Beton Element 250']
# Bips - Beton Element 250
# Products:
# Bips - Beton Element
# Amount from layer:
# 250
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.25
# Added construction
# (22)13 - Loftskjørt
# 187.20000000000013
# Layers:
# ['By Category 70', 'Gips 13']
# By Category 70
# Products:
# By Category
# Amount from layer:
# 70
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)13 - Loftskjørt (1 lag gips)
# 14.59
# Layers:
# ['Bips - Isolering Blød kl 34 50', 'Gips 13']
# Bips - Isolering Blød kl 34 50
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 50
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.05
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)2 - Lette Indervægge
# 94.69000000000001
# Layers:
# ['Bips - Isolering Blød kl 34 70', 'Gips 13']
# Bips - Isolering Blød kl 34 70
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 70
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)3 - Lette indervægge - Vådrum
# 2050.8600000000097
# Layers:
# ['Bips - Isolering Blød kl 34 95', 'Gips 13']
# Bips - Isolering Blød kl 34 95
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 95
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.095
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)4 - Forsatsvægge
# 210.42000000000002
# Layers:
# ['Bips - Isolering Blød kl 34 70', 'Gips 13']
# Bips - Isolering Blød kl 34 70
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 70
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)5 - Forsatsvægge vådrum
# 804.9700000000026
# Layers:
# ['Bips - Isolering Blød kl 34 70', 'Gips 13']
# Bips - Isolering Blød kl 34 70
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 70
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)6 - Tung skillevæg - 200 mm beton
# 695.5699999999999
# Layers:
# ['Bips - Beton Element 200']
# Bips - Beton Element 200
# Products:
# Bips - Beton Element
# Amount from layer:
# 200
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.2
# Added construction
# (22)6 Lejlighedsskel
# 2001.9600000000003
# Layers:
# ['By Category 10', 'Bips - Isolering Blød kl 34 70', 'Gips 13']
# By Category 10
# Products:
# By Category
# Amount from layer:
# 10
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.01
# Bips - Isolering Blød kl 34 70
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 70
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.07
# Gips 13
# Products:
# Gips
# Amount from layer:
# 13
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.013
# Added construction
# (22)8 - Tung skillevæg - 180 mm beton
# 3933.06
# Layers:
# ['Bips - Beton Element 180']
# Bips - Beton Element 180
# Products:
# Bips - Beton Element
# Amount from layer:
# 180
# M3
# Productid:
# 6ab47d6b-8c6a-42fb-ae05-68ddeca7498f
# LCABYG Name:
# Bips - Beton Element
# Final amount:
# 0.18

# %%
# L23
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L23['Sum of Area'],L23['Row Labels'], '23. ETAGEDÆK',  L23['Unit'], L23['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 23. ETAGEDÆK
# Added construction
# (23)1 - Etagedæk over kælder, stue, 1. 2 sal.
# 4756.0
# Layers:
# ['BA - f2 - Beton-Insitu 80', 'Bips - Isolering Blød kl 34 50']
# BA - f2 - Beton-Insitu 80
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 80
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.08
# Bips - Isolering Blød kl 34 50
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 50
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.05
# Added construction
# (23)1 Etagedæk over kælder, stue, 1, 2. sal (Huldæk)
# 6017.0
# Layers:
# ['BA - f2 - Beton-Element 220']
# BA - f2 - Beton-Element 220
# Products:
# BA - f2 - Beton-Element
# Amount from layer:
# 220
# M3
# Productid:
# 20a22049-06d1-46bd-9069-1ce3564714c4
# LCABYG Name:
# BA - (f2) - Beton-Element
# Final amount:
# 0.22
# Added construction
# (23)2 - Etagedæk over kælder, stue, 1. 2 sal. Vådrum
# 530.0
# Layers:
# ['BA - f2 - Beton-Insitu 80', 'Bips - Isolering Hård 50']
# BA - f2 - Beton-Insitu 80
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 80
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.08
# Bips - Isolering Hård 50
# Products:
# Bips - Isolering Hård
# Amount from layer:
# 50
# M3
# Productid:
# 5c47997c-4bdb-492d-8ce3-f5fcb097b061
# LCABYG Name:
# XPS isolering
# Final amount:
# 0.05
# Added construction
# (23)3 - Etagedæk ved Spa område
# 456.0
# Layers:
# ['By Category 630']
# By Category 630
# Products:
# By Category
# Amount from layer:
# 630
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.63
# Added construction
# (23)4 - Etagedæk ved orangeri
# 106.0
# Layers:
# ['BA - f2 - Beton-Insitu 80', 'Bips - Isolering Hård 50']
# BA - f2 - Beton-Insitu 80
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 80
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.08
# Bips - Isolering Hård 50
# Products:
# Bips - Isolering Hård
# Amount from layer:
# 50
# M3
# Productid:
# 5c47997c-4bdb-492d-8ce3-f5fcb097b061
# LCABYG Name:
# XPS isolering
# Final amount:
# 0.05
# Added construction
# (23)4 - Etagedæk ved orangeri - Underkonstruktion
# 120.0
# Layers:
# ['By Category 25', 'Bips - Gips 15', 'Bips - Isolering Hård 90']
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Gips 15
# Products:
# Bips - Gips
# Amount from layer:
# 15
# KG
# Productid:
# ba75e1e4-ca89-45de-ba48-1e74f32a34ae
# LCABYG Name:
# Bips - Gips
# Final amount:
# 0.015
# Bips - Isolering Hård 90
# Products:
# Bips - Isolering Hård
# Amount from layer:
# 90
# M3
# Productid:
# 5c47997c-4bdb-492d-8ce3-f5fcb097b061
# LCABYG Name:
# XPS isolering
# Final amount:
# 0.09
# Added construction
# (23)4 - Trappe repos
# 106.0
# Layers:
# ['BA - f2 - Beton-Insitu 220']
# BA - f2 - Beton-Insitu 220
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 220
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.22
# Added construction
# (23)x massiv dæk
# 153.0
# Layers:
# ['BA - f2 - Beton-Element 220']
# BA - f2 - Beton-Element 220
# Products:
# BA - f2 - Beton-Element
# Amount from layer:
# 220
# M3
# Productid:
# 20a22049-06d1-46bd-9069-1ce3564714c4
# LCABYG Name:
# BA - (f2) - Beton-Element
# Final amount:
# 0.22
# Added construction
# (27)14 - Etagedæk og loftopbygning over hovedindgang
# 20.0
# Layers:
# ['By Category 95', 'Bips - Gips 15', 'Bips - Isolering Hård 200']
# By Category 95
# Products:
# By Category
# Amount from layer:
# 95
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.095
# Bips - Gips 15
# Products:
# Bips - Gips
# Amount from layer:
# 15
# KG
# Productid:
# ba75e1e4-ca89-45de-ba48-1e74f32a34ae
# LCABYG Name:
# Bips - Gips
# Final amount:
# 0.015
# Bips - Isolering Hård 200
# Products:
# Bips - Isolering Hård
# Amount from layer:
# 200
# M3
# Productid:
# 5c47997c-4bdb-492d-8ce3-f5fcb097b061
# LCABYG Name:
# XPS isolering
# Final amount:
# 0.2
# Added construction
# BA-X-concPC-350
# 84.0
# Layers:
# ['BA - f2 - Beton-Insitu 350']
# BA - f2 - Beton-Insitu 350
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 350
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.35
# Added construction
# BA-X-concPC-1000
# 9.0
# Layers:
# ['Betong - Prefab 1000']
# Betong - Prefab 1000
# Products:
# Betong - Prefab
# Amount from layer:
# 1000
# M3
# Productid:
# 28ea48d9-ae49-4351-9463-87601417f271
# LCABYG Name:
# Betong - Prefab
# Final amount:
# 1.0
# Added construction
# BA-X-Sti
# 1400.0
# Layers:
# ['Site - Sand 300']
# Site - Sand 300
# Products:
# Site - Sand
# Amount from layer:
# 300
# KG
# Productid:
# decdfa16-2cee-44b9-9663-4ad47668c4cb
# LCABYG Name:
# Site - Sand
# Final amount:
# 450.0
# Added construction
# BA-X-Vej
# 8839.0
# Layers:
# ['BA - n9 - Asfalt 300']
# BA - n9 - Asfalt 300
# Products:
# BA - n9 - Asfalt
# Amount from layer:
# 300
# KG
# Productid:
# 86f6f36a-ffb5-46e4-97c2-5a2c4c697352
# LCABYG Name:
# BA - n9 - Asfalt
# Final amount:
# 480.0
# Added construction
# Bundplade 500
# 2474.0
# Layers:
# ['BA - f2 - Beton-Insitu 500']
# BA - f2 - Beton-Insitu 500
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 500
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.5
# Added construction
# Bundplade 700
# 876.0
# Layers:
# ['BA - f2 - Beton-Insitu 700']
# BA - f2 - Beton-Insitu 700
# Products:
# BA - f2 - Beton-Insitu
# Amount from layer:
# 700
# M3
# Productid:
# 8a468320-3e31-48c3-a912-3d5cc90771b4
# LCABYG Name:
# BA - (f2) - Beton-Insitu
# Final amount:
# 0.7
# Added construction
# Huldæk over Elevator
# 15.0
# Layers:
# ['BA - f2 - Beton-Element 220', 'BA - n2 - Tagpap 8', 'Bips - Polystyren 500']
# BA - f2 - Beton-Element 220
# Products:
# BA - f2 - Beton-Element
# Amount from layer:
# 220
# M3
# Productid:
# 20a22049-06d1-46bd-9069-1ce3564714c4
# LCABYG Name:
# BA - (f2) - Beton-Element
# Final amount:
# 0.22
# BA - n2 - Tagpap 8
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 8
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 500
# Products:
# Bips - Polystyren
# Amount from layer:
# 500
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.5
# Added construction
# Klinker 15 mm
# 14.0
# Layers:
# ['Klinker 15']
# Klinker 15
# Products:
# Klinker
# Amount from layer:
# 15
# M3
# Productid:
# 1647ea0e-3c83-411c-a492-d82d4ea55894
# LCABYG Name:
# Klinker
# Final amount:
# 0.015
# Added construction
# Pool 1 - Konstruktionopbygning - Under konstruktion
# 64.0
# Layers:
# ['By Category 25', 'Bips - Polystyren 150', 'Gips 15']
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Polystyren 150
# Products:
# Bips - Polystyren
# Amount from layer:
# 150
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.15
# Gips 15
# Products:
# Gips
# Amount from layer:
# 15
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.015
# Added construction
# Repos Spindeltrappe
# 685.0
# Layers:
# ['Maling Hvid Mat 50']
# Maling Hvid Mat 50
# Products:
# Maling Hvid Mat
# Amount from layer:
# 50
# KG
# Productid:
# 1cde6c1c-7b19-454d-93b2-c8b1225f58a9
# LCABYG Name:
# Maling Hvid Mat
# Final amount:
# 0.05

# %%
# L27
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L27['Sum of Area'],L27['Row Labels'], '27. TAGE',  L27['Unit'], L27['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 27. TAGE
# Added construction
# (27)1 - Tagkonstruktion Øst fløj
# 250.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)2 - Tagkonstruktion/Tagterasse - Nordfløj
# 510.0
# Layers:
# ['By Category 200', 'BA - n2 - Tagpap 10', 'Bips - Polystyren 400', 'Roofing 20']
# By Category 200
# Products:
# By Category
# Amount from layer:
# 200
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.2
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 400
# Products:
# Bips - Polystyren
# Amount from layer:
# 400
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.4
# Roofing 20
# Products:
# Roofing
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# 24404a3c-56ce-4117-80b9-51c6e4006937
# LCABYG Name:
# Roofing
# Final amount:
# 1.0
# Added construction
# (27)3 - Tagkonstruktion Nord fløj
# 60.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)4 - Tagkonstruktion -  Terasse mod Øst/Vest
# 304.0
# Layers:
# ['By Category 170', 'BA - n2 - Tagpap 10', 'Bips - Polystyren 400', 'Tagfliser 50']
# By Category 170
# Products:
# By Category
# Amount from layer:
# 170
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.17
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 400
# Products:
# Bips - Polystyren
# Amount from layer:
# 400
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.4
# Tagfliser 50
# Products:
# Tagfliser
# Amount from layer:
# 50
# _________
# 1.0
# M2
# Productid:
# 45a5cd65-1aba-4c0e-86cb-9164c137d933
# LCABYG Name:
# Tagfliser
# Final amount:
# 1.0
# Added construction
# (27)5 - Tagkonstruktion -  Terasse ved Syd fløj
# 56.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)5 - Tagkonstruktion -  Terasse ved Syd fløj - Top konstruktion
# 56.0
# Layers:
# ['Tagfliser 20']
# Tagfliser 20
# Products:
# Tagfliser
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# 45a5cd65-1aba-4c0e-86cb-9164c137d933
# LCABYG Name:
# Tagfliser
# Final amount:
# 1.0
# Added construction
# (27)6 - Tagkonstruktion Vestfløj over Personale
# 102.0
# Layers:
# ['BA - n2 - Tagpap 10', 'Bips - Polystyren 500']
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 500
# Products:
# Bips - Polystyren
# Amount from layer:
# 500
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.5
# Added construction
# (27)7 - Tagkonstruktion Vestfløj over personale
# 16.0
# Layers:
# ['By Category 170', 'BA - n2 - Tagpap 10', 'Bips - Polystyren 310', 'Roofing 20']
# By Category 170
# Products:
# By Category
# Amount from layer:
# 170
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.17
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 310
# Products:
# Bips - Polystyren
# Amount from layer:
# 310
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.31
# Roofing 20
# Products:
# Roofing
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# 24404a3c-56ce-4117-80b9-51c6e4006937
# LCABYG Name:
# Roofing
# Final amount:
# 1.0
# Added construction
# (27)8 - Tagkonstruktion
# 30.0
# Layers:
# ['BA - n2 - Tagpap 10', 'Bips - Isolering Blød kl 34 500']
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Isolering Blød kl 34 500
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 500
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.5
# Added construction
# (27)9 - Tagkonstruktion Syd fløj
# 736.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)10 - Tagkonstruktion (75 grader)
# 942.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)12 - Tagkonstruktion ved Trapperum H og elevator
# 104.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)12 - Tagkonstruktion ved Trapperum H og elevator - Flad del
# 70.0
# Layers:
# ['BA - n2 - Tagpap 8', 'Bips - Polystyren 500']
# BA - n2 - Tagpap 8
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 8
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Polystyren 500
# Products:
# Bips - Polystyren
# Amount from layer:
# 500
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.5
# Added construction
# (27)13 - Tagkonstruktion ved trapperum L og elevator tårn - Nordfløj
# 54.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# (27)14 - Tagkonstruktion
# 27.0
# Layers:
# ['By Category 18', 'By Category 19', 'BA - n2 - Tagpap 10', 'BA - x - Luft 60', 'Bips - Gips 13', 'Bips - Isolering Blød kl 34 95', 'Bips - Isolering Blød kl 34 145', 'Bips - Isolering Blød kl 34 295']
# By Category 18
# Products:
# By Category
# Amount from layer:
# 18
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.018
# By Category 19
# Products:
# By Category
# Amount from layer:
# 19
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.019
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# BA - x - Luft 60
# Products:
# BA - x - Luft
# Amount from layer:
# 60
# M3
# Productid:
# 424e31c0-f0a3-4f4d-a446-ca3b5ace4cac
# LCABYG Name:
# BA - (x) - Luft
# Final amount:
# 0.06
# Bips - Gips 13
# Products:
# Bips - Gips
# Amount from layer:
# 13
# KG
# Productid:
# ba75e1e4-ca89-45de-ba48-1e74f32a34ae
# LCABYG Name:
# Bips - Gips
# Final amount:
# 0.013
# Bips - Isolering Blød kl 34 95
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 95
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.095
# Bips - Isolering Blød kl 34 145
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 145
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.145
# Bips - Isolering Blød kl 34 295
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 295
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.295
# Added construction
# (27)14 - Tagkonstruktion (Overdel)
# 101.0
# Layers:
# ['By Category 18', 'BA - n2 - Tagpap 10', 'BA - x - Luft 60']
# By Category 18
# Products:
# By Category
# Amount from layer:
# 18
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.018
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# BA - x - Luft 60
# Products:
# BA - x - Luft
# Amount from layer:
# 60
# M3
# Productid:
# 424e31c0-f0a3-4f4d-a446-ca3b5ace4cac
# LCABYG Name:
# BA - (x) - Luft
# Final amount:
# 0.06
# Added construction
# (27)14 - Tagkonstruktion Midterdel
# 103.0
# Layers:
# ['Bips - Isolering Blød kl 34 145', 'Bips - Isolering Blød kl 34 295']
# Bips - Isolering Blød kl 34 145
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 145
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.145
# Bips - Isolering Blød kl 34 295
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 295
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.295
# Added construction
# Karnap tag
# 5.0
# Layers:
# ['By Category 125']
# By Category 125
# Products:
# By Category
# Amount from layer:
# 125
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.125
# Added construction
# Kvisttag
# 122.0
# Layers:
# ['BA - f7 - Gipsvæg 15', 'Bips - Isolering Blød kl 34 45', 'Bips - Isolering Blød kl 34 195']
# BA - f7 - Gipsvæg 15
# Products:
# BA - f7 - Gipsvæg
# Amount from layer:
# 15
# KG
# Productid:
# efc3b3da-f156-4682-92c3-98fb6aa1662e
# LCABYG Name:
# BA - (f7) - Gips(væg)
# Final amount:
# 0.015
# Bips - Isolering Blød kl 34 45
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 45
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.045
# Bips - Isolering Blød kl 34 195
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 195
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.195
# Added construction
# Kvisttag 2
# 6.0
# Layers:
# ['BA - f7 - Gipsvæg 13', 'Bips - Isolering Blød kl 34 45', 'Bips - Isolering Blød kl 34 195']
# BA - f7 - Gipsvæg 13
# Products:
# BA - f7 - Gipsvæg
# Amount from layer:
# 13
# KG
# Productid:
# efc3b3da-f156-4682-92c3-98fb6aa1662e
# LCABYG Name:
# BA - (f7) - Gips(væg)
# Final amount:
# 0.013
# Bips - Isolering Blød kl 34 45
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 45
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.045
# Bips - Isolering Blød kl 34 195
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 195
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.195
# Added construction
# Sloped Glazing
# 1.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# tag kvist
# 3.0
# Layers:
# ['Reinf Concrete 25']
# Reinf Concrete 25
# Products:
# Reinf Concrete
# Amount from layer:
# 25
# M3
# Productid:
# 060433ef-da27-42e8-913a-f0a53ea669c5
# LCABYG Name:
# NO INFO / Beton C25/30, fabriksbeton og betonelementer
# Final amount:
# 0.025
# Added construction
# TagDæk
# 1154.0
# Layers:
# ['BA - f2 - Beton-Element 220']
# BA - f2 - Beton-Element 220
# Products:
# BA - f2 - Beton-Element
# Amount from layer:
# 220
# M3
# Productid:
# 20a22049-06d1-46bd-9069-1ce3564714c4
# LCABYG Name:
# BA - (f2) - Beton-Element
# Final amount:
# 0.22
# Added construction
# tagkonstruktion på elevator
# 7.0
# Layers:
# ['BA - n2 - Tagpap 10', 'Bips - Isolering Blød kl 34 500']
# BA - n2 - Tagpap 10
# Products:
# BA - n2 - Tagpap
# Amount from layer:
# 10
# _________
# 1.0
# M2
# Productid:
# b8afe642-ab4f-45f0-b205-ff4a7c3e7840
# LCABYG Name:
# BA - (n2) - Tagpap
# Final amount:
# 1.0
# Bips - Isolering Blød kl 34 500
# Products:
# Bips - Isolering Blød kl 34
# Amount from layer:
# 500
# M3
# Productid:
# d31dba83-e710-41c4-aa98-61f69598d369
# LCABYG Name:
# Bips - Isolering Blød kl 34
# Final amount:
# 0.5
# Added construction
# Underkonstruktion
# 91.0
# Layers:
# ['By Category 25', 'Bips - Polystyren 150', 'Gips 15']
# By Category 25
# Products:
# By Category
# Amount from layer:
# 25
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.025
# Bips - Polystyren 150
# Products:
# Bips - Polystyren
# Amount from layer:
# 150
# M3
# Productid:
# 436b04f7-0a81-4f07-b6f6-e2bc3d500091
# LCABYG Name:
# EPS isolering til vægge og tage 035
# Final amount:
# 0.15
# Gips 15
# Products:
# Gips
# Amount from layer:
# 15
# KG
# Productid:
# 56a43281-b3e7-459c-bdd6-fe5c949fa6f2
# LCABYG Name:
# Gips
# Final amount:
# 0.015
# Added construction
# zink 80
# 237.0
# Layers:
# ['Bips - Træ 25', 'Skiffer 80']
# Bips - Træ 25
# Products:
# Bips - Træ
# Amount from layer:
# 25
# M3
# Productid:
# 9c9cc50d-e76a-45cf-bfd2-d9eabc26ed55
# LCABYG Name:
# Bips - Træ
# Final amount:
# 0.025
# Skiffer 80
# Products:
# Skiffer
# Amount from layer:
# 80
# _________
# 1.0
# M2
# Productid:
# d01ac82c-1522-4ed8-a1ab-299678bdf54c
# LCABYG Name:
# Skiffer
# Final amount:
# 1.0

# %%
# L31
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L31['Sum of Area'],L31['Row Labels'], '31. YDERVÆGGE, KOMPLETTERING',  L31['Unit'], L31['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 31. YDERVÆGGE, KOMPLETTERING

# %%
# L43
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L43['Sum of Area'],L43['Row Labels'], '43. GULVE',  L43['Unit'], L43['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 43. GULVE
# Added construction
# FP01 Trægulv 21 mm
# 1256.0
# Layers:
# ['Trægulv FP01 20']
# Trægulv FP01 20
# Products:
# Trægulv FP01
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# e8f5aad5-882d-4cf5-8486-f291eb27cfa6
# LCABYG Name:
# Trægulv FP01
# Final amount:
# 1.0
# Added construction
# FP04 Terrazzogulv 15 mm
# 78.0
# Layers:
# ['Terrazzogulv 15']
# Terrazzogulv 15
# Products:
# Terrazzogulv
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 8b0333cb-296b-40d4-b317-66adfbfa14be
# LCABYG Name:
# Terrazzogulv
# Final amount:
# 1.0
# Added construction
# FP06 gulvtæppe 15 mm
# 228.0
# Layers:
# ['Gulvtæppe FP06 15']
# Gulvtæppe FP06 15
# Products:
# Gulvtæppe FP06
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 7fb431e7-624a-4049-9089-8742844da2f2
# LCABYG Name:
# Gulvtæppe FP06
# Final amount:
# 1.0
# Added construction
# FP07 Mosaik 15 mm
# 52.0
# Layers:
# ['Mosaikgulv 15']
# Mosaikgulv 15
# Products:
# Mosaikgulv
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 0ea3738f-600d-45be-bb2d-62a20dc51a4a
# LCABYG Name:
# Mosaikgulv
# Final amount:
# 1.0
# Added construction
# FP08 Mosaik 20 mm
# 103.0
# Layers:
# ['Mosaikgulv FP08 20']
# Mosaikgulv FP08 20
# Products:
# Mosaikgulv FP08
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# 45b5cc79-b927-4ee7-a326-02fdb9f871f9
# LCABYG Name:
# Mosaikgulv FP08
# Final amount:
# 1.0
# Added construction
# FP09 Trægulv 21 mm
# 234.0
# Layers:
# ['Trægulv FP09 21']
# Trægulv FP09 21
# Products:
# Trægulv FP09
# Amount from layer:
# 21
# _________
# 1.0
# M2
# Productid:
# 49362f90-149b-4ec2-9c54-6f74c4e046ef
# LCABYG Name:
# Trægulv FP09
# Final amount:
# 1.0
# Added construction
# FP10 gulvtæppe 15 mm
# 113.0
# Layers:
# ['Gulvtæppe FP10 15']
# Gulvtæppe FP10 15
# Products:
# Gulvtæppe FP10
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# d3ab9431-80fe-47dc-9978-b779b5d01517
# LCABYG Name:
# Gulvtæppe FP10
# Final amount:
# 1.0
# Added construction
# FP11 gulvtæppe 15 mm
# 156.0
# Layers:
# ['Gulvtæppe FP11 15']
# Gulvtæppe FP11 15
# Products:
# Gulvtæppe FP11
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 16e6d002-ab98-4c91-a915-4ce2fd0226d1
# LCABYG Name:
# Gulvtæppe FP11
# Final amount:
# 1.0
# Added construction
# FP12 gulvtæppe 15 mm
# 291.0
# Layers:
# ['Gulvtæppe FP12 15']
# Gulvtæppe FP12 15
# Products:
# Gulvtæppe FP12
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 274fd34d-de30-47bc-bc32-a26728823a33
# LCABYG Name:
# Gulvtæppe FP12
# Final amount:
# 1.0
# Added construction
# FP14 Massagolv 25 mm
# 10.0
# Layers:
# ['FP14 Stengulv 25']
# FP14 Stengulv 25
# Products:
# FP14 Stengulv
# Amount from layer:
# 25
# _________
# 1.0
# M2
# Productid:
# e4762931-1b74-4f55-831e-59244d1429cb
# LCABYG Name:
# FP14 Stengulv
# Final amount:
# 1.0
# Added construction
# FP16 Massagolv 20 mm
# 349.0
# Layers:
# ['Massagolv FP16 20']
# Massagolv FP16 20
# Products:
# Massagolv FP16
# Amount from layer:
# 20
# _________
# 1.0
# M2
# Productid:
# 27b22294-0aeb-420b-9418-5a10c798d5cd
# LCABYG Name:
# Massagolv FP16
# Final amount:
# 1.0
# Added construction
# FP17 gulvtæppe 15 mm
# 20.0
# Layers:
# ['Gulvtæppe FP17 15']
# Gulvtæppe FP17 15
# Products:
# Gulvtæppe FP17
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 399403f2-78ae-40f4-af46-6b085e538a1e
# LCABYG Name:
# Gulvtæppe FP17
# Final amount:
# 1.0
# Added construction
# FP18 Mosaik 15 mm
# 37.0
# Layers:
# ['Mosaikgulv FP18 15']
# Mosaikgulv FP18 15
# Products:
# Mosaikgulv FP18
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 729483b5-a429-4e0f-90de-55429dff6ef9
# LCABYG Name:
# Mosaikgulv FP18
# Final amount:
# 1.0
# Added construction
# Gulv bad Hotelværelser
# 603.0
# Layers:
# ['Fliser Bad gulv 15']
# Fliser Bad gulv 15
# Products:
# Fliser Bad gulv
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 21f3dae4-3b11-4adf-82a3-5b396b3ead88
# LCABYG Name:
# Fliser Bad gulv
# Final amount:
# 1.0
# Added construction
# Gulv gang
# 195.0
# Layers:
# ['By Category 15']
# By Category 15
# Products:
# By Category
# Amount from layer:
# 15
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.015
# Added construction
# Gulv Hotelværelser
# 2520.0
# Layers:
# ['By Category 15']
# By Category 15
# Products:
# By Category
# Amount from layer:
# 15
# M3
# Productid:
# b120fb03-7bb3-4be9-aff1-c37771850179
# LCABYG Name:
# <By Category>
# Final amount:
# 0.015
# Added construction
# Gulvfliser
# 159.0
# Layers:
# ['Fliser Bad gulv 15']
# Fliser Bad gulv 15
# Products:
# Fliser Bad gulv
# Amount from layer:
# 15
# _________
# 1.0
# M2
# Productid:
# 21f3dae4-3b11-4adf-82a3-5b396b3ead88
# LCABYG Name:
# Fliser Bad gulv
# Final amount:
# 1.0

# %%
# L45
lcabyg_elements = lcabygjson.append_lcabyg_element(lcabyg_elements,L45['Sum of Area'],L45['Row Labels'], '45. LOFTER',  L45['Unit'], L45['Layers'], products_df, str(uuid.uuid4()))
# Out:
# Added element:
# 45. LOFTER

# %%
lcabyg_elements
# Out:
# ([{'Node': {'Element': {'id': '02c3e303-a443-4f02-9927-e43519227ade',
#      'name': {'Danish': '12. FUNDAMENTER', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Node': {'Element': {'id': '369e52a6-7c8b-436b-bbd0-60e22ed8c7b2',
#      'name': {'Danish': '13. TERRÆNDÆK', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': 'fa6b292b-3d75-4539-a451-9c3eceda9525',
#       'amount': 633.0,
#       'enabled': True}},
#     '369e52a6-7c8b-436b-bbd0-60e22ed8c7b2',
#     'ad379824-4121-4fe4-bcc9-370d18290b4c']},
#   {'Edge': [{'ElementToConstruction': {'id': '92802657-17ae-4d55-9cd7-834a133a51ab',
#       'amount': 147.0,
#       'enabled': True}},
#     '369e52a6-7c8b-436b-bbd0-60e22ed8c7b2',
#     'b9b89dee-194a-41cd-b245-0dd3b8bdad92']},
#   {'Edge': [{'ElementToConstruction': {'id': 'ac2c6a30-e070-4c70-807f-e8b29800d37d',
#       'amount': 2139.0,
#       'enabled': True}},
#     '369e52a6-7c8b-436b-bbd0-60e22ed8c7b2',
#     '727a31e9-6aef-4793-b5d3-baff00f77cb9']},
#   {'Edge': [{'ElementToConstruction': {'id': '9bbbc40b-6bf6-40ee-a192-9c0b52dd11c9',
#       'amount': 114.0,
#       'enabled': True}},
#     '369e52a6-7c8b-436b-bbd0-60e22ed8c7b2',
#     '00139490-43c6-4e16-b89c-2901b967276c']},
#   {'Node': {'Element': {'id': '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#      'name': {'Danish': '21. YDERVÆGGE', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': 'ee8e6f5d-f828-40c9-96c2-891110b95401',
#       'amount': 138.45,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'fa96455b-540d-49a4-a62c-bc75e49070e8']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c06510b3-8e5e-4625-a85f-978e7f0d9ff5',
#       'amount': 603.01,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '087432a2-6c9a-4a4e-ae53-b516e4af640c']},
#   {'Edge': [{'ElementToConstruction': {'id': '091dc8e1-c77d-4812-88f0-6233443e4231',
#       'amount': 2368.729999999999,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'a2d3eff5-ebd4-4216-b4ee-e69eb2b229c2']},
#   {'Edge': [{'ElementToConstruction': {'id': '5b1e2698-19b1-41bf-aedb-6ff357a6281a',
#       'amount': 412.1900000000002,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '2b4aa808-1010-4f5b-a07a-1e182661049e']},
#   {'Edge': [{'ElementToConstruction': {'id': 'e074b0de-2c0e-490c-8f46-891d72d4a805',
#       'amount': 1.56,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '2deb2b6c-abcc-4b8a-9087-869b96d4cd5f']},
#   {'Edge': [{'ElementToConstruction': {'id': '974c3e7a-f5fc-420f-8886-51a94c5d54ab',
#       'amount': 35.129999999999995,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '8d2cdf68-758c-41eb-be00-38423304f683']},
#   {'Edge': [{'ElementToConstruction': {'id': 'cb923df3-2d3f-4e20-8509-b3b1578f2c44',
#       'amount': 4.54,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '19b6741c-a425-49c4-8369-4147aa300278']},
#   {'Edge': [{'ElementToConstruction': {'id': '3cf54a23-be5d-46a6-9dc0-7210c9504f1e',
#       'amount': 42.0,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435']},
#   {'Edge': [{'ElementToConstruction': {'id': '03535c5c-d909-4679-8b5c-af97b29acfe5',
#       'amount': 5.02,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'a32038a5-5757-47d7-9dd2-c14db9afa1bd']},
#   {'Edge': [{'ElementToConstruction': {'id': '398cab12-17d8-4a1d-b189-81d24a221340',
#       'amount': 5.08,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'eb403a0a-fa32-4ff7-a7f0-dfe66ce72d74']},
#   {'Edge': [{'ElementToConstruction': {'id': '41982360-468b-4c06-8c9f-8855bd790ab6',
#       'amount': 7.5,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '3b3bf21d-95ad-4f55-8abb-8ccdd41a6c35']},
#   {'Edge': [{'ElementToConstruction': {'id': 'dae83205-c86c-4b78-b538-908933a65fbf',
#       'amount': 15.12,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'ef9175bc-3642-4bde-980b-d04ef9590f9e']},
#   {'Edge': [{'ElementToConstruction': {'id': 'f05c1deb-bbb7-41e0-8fc3-5f7b1f1088cd',
#       'amount': 5.24,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '61f388c5-28a6-4583-9639-ec794907d52e']},
#   {'Edge': [{'ElementToConstruction': {'id': '7d1a90ed-be6c-4756-8410-393f97117d70',
#       'amount': 5.24,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '1fe6e0cd-a01c-4467-bb96-62caa789b335']},
#   {'Edge': [{'ElementToConstruction': {'id': '36b4d2fc-eb9b-49c1-8158-087d6d9e7ca0',
#       'amount': 5.24,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     

#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '6fef49af-0b75-403a-bf9e-8a2eac3d5698']},
#   {'Edge': [{'ElementToConstruction': {'id': '46b04222-2fcc-4bd9-a67b-5c8e470ebde0',
#       'amount': 8.76,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '5de3f445-cca7-4c9c-aed3-e221d5134c05']},
#   {'Edge': [{'ElementToConstruction': {'id': 'a1bc09af-0763-4f9f-9a95-c829cde24ce3',
#       'amount': 8.76,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'f174d30b-c247-4a2b-ae66-2275da9b8356']},
#   {'Edge': [{'ElementToConstruction': {'id': 'cb5944e6-ac7d-426a-8d15-415435db3852',
#       'amount': 4.37,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '5411d164-6b9b-46dc-b80e-01a1fdb7fd74']},
#   {'Edge': [{'ElementToConstruction': {'id': 'eddac0cd-d3db-4046-abb9-aac744453a4a',
#       'amount': 4.37,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '40a1403c-d6b5-4446-86bd-b9e18e455833']},
#   {'Edge': [{'ElementToConstruction': {'id': '145fa41c-6a48-4d19-aa01-dd878556c8a6',
#       'amount': 4.37,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '2d4190ac-74a1-4dd4-9565-aaf362863a41']},
#   {'Edge': [{'ElementToConstruction': {'id': 'cb0b55f1-ff5a-47cc-b08f-15c8a404965e',
#       'amount': 5.76,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '48c4256b-23f8-4396-a76b-64d9622a3d17']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c95f265f-f384-4ffa-a7f9-a31f9c61ec4b',
#       'amount': 5.76,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'c4f1a1fd-a346-434e-a222-135c89c444cf']},
#   {'Edge': [{'ElementToConstruction': {'id': '316e39c6-29e1-4873-b872-27ef6f01114d',
#       'amount': 14.15,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'd7df4d55-0b3e-4a54-b974-89d71d1a8d31']},
#   {'Edge': [{'ElementToConstruction': {'id': '0360274c-ebcf-421c-8dae-b12509d95509',
#       'amount': 103.56,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     'c2c4c6c2-2b7a-40e4-825c-3604da587d70']},
#   {'Edge': [{'ElementToConstruction': {'id': 'b54b13a4-8968-4dfe-b1e1-1307ddac32a9',
#       'amount': 154.54000000000002,
#       'enabled': True}},
#     '19e88127-1734-452d-b6bd-5fdf5ad0d3e5',
#     '1e6ad351-5f6f-41d9-b63a-996f32e86958']},
#   {'Node': {'Element': {'id': 'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#      'name': {'Danish': '22. INDERVÆGGE', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': 'ac7abdea-2432-42a7-b6d2-84e9fa287714',
#       'amount': 12.250000000000002,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'b017182c-0821-4df9-957e-e3b35f9cac11']},
#   {'Edge': [{'ElementToConstruction': {'id': '648ec45c-7326-404a-9cca-428c07e6bf0a',
#       'amount': 1347.3700000000003,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '19ddec42-fc89-4fff-8c42-654794d0985a']},
#   {'Edge': [{'ElementToConstruction': {'id': '9a3721a1-13a0-42d2-94f5-267e32921305',
#       'amount': 178.66999999999987,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '4724f09a-6317-44af-a688-12096782f6d5']},
#   {'Edge': [{'ElementToConstruction': {'id': 'b5bfe2a2-478a-4305-aeaa-2f516dfdc4ee',
#       'amount': 43.66,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '7089e7c0-a516-4bfc-9b09-90d46ddd8665']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c11436d5-6bbb-4f46-b180-00774686339d',
#       'amount': 187.20000000000013,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '04b742f5-f628-4a52-b4f1-7d7813652285']},
#   {'Edge': [{'ElementToConstruction': {'id': '08dcd643-b0e4-47d8-80be-93fc684d131c',
#       'amount': 14.59,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'c2a58c61-320a-4e89-81f6-02874f70fe04']},
#   {'Edge': [{'ElementToConstruction': {'id': '6134397f-bd67-413a-9210-a774626f90a9',
#       'amount': 94.69000000000001,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'bc44b241-e414-4c49-8734-6645e45dda49']},
#   {'Edge': [{'ElementToConstruction': {'id': '53415ec4-79cc-4c4b-ba9d-c2e4c9ca4692',
#       'amount': 2050.8600000000097,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'd41f5dce-894e-44bf-9916-f6d46a60f3b8']},
#   {'Edge': [{'ElementToConstruction': {'id': '2d339e7b-04c9-4a56-a3a1-1a1bac4ff33e',
#       'amount': 210.42000000000002,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '863a2091-0ae5-4c23-8c61-089186e97c94']},
#   {'Edge': [{'ElementToConstruction': {'id': 'e1f61565-b093-4487-9c99-ff81a45d433e',
#       'amount': 804.9700000000026,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '055cea50-428a-4708-870a-de0bd23e5986']},
#   {'Edge': [{'ElementToConstruction': {'id': '8d48bd92-0dea-4ea4-a7ec-100f863ef986',
#       'amount': 695.5699999999999,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     '5fbdf363-01e9-48ae-a0fe-ff15dffd7e46']},
#   {'Edge': [{'ElementToConstruction': {'id': 'a4b8218f-7168-4df3-addf-fbf395ee7847',
#       'amount': 2001.9600000000003,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'af741350-e06a-4798-b1a3-2d0b018f5af7']},
#   {'Edge': [{'ElementToConstruction': {'id': 'b5d81968-7e36-4340-856d-b2c24f59a709',
#       'amount': 3933.06,
#       'enabled': True}},
#     'b38d501c-0fd6-4bcd-a436-1ff281e9ac49',
#     'c5690d94-bbfd-4324-ab97-7e34fabbaac3']},
#   {'Node': {'Element': {'id': '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#      'name': {'Danish': '23. ETAGEDÆK', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': '88ffd43e-4052-4490-a127-19214cdf5b29',
#       'amount': 4756.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '7e8bdf4a-25d8-43e1-b84c-2949acf6f107']},
#   {'Edge': [{'ElementToConstruction': {'id': 'fe57a1b8-8104-4da3-8a59-c7c8c8342f9c',
#       'amount': 6017.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'c3b8a293-16f1-4bae-bc5f-dd003cbc82d5']},
#   {'Edge': [{'ElementToConstruction': {'id': 'de1d86ac-f321-4ae9-b5a7-d3efcce023ee',
#       'amount': 530.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '7cffcaa7-b8ac-404a-a6a6-2754efcc3f8b']},
#   {'Edge': [{'ElementToConstruction': {'id': '78d421cd-b8ef-4c11-b966-dabdf06dbcf6',
#       'amount': 456.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '692b6c06-6011-4258-bdb9-da134702f5ce']},
#   {'Edge': [{'ElementToConstruction': {'id': '1239ddf8-44a3-4c96-9623-ea6085003878',
#       'amount': 106.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'd7d40940-ec27-48a6-a0b6-71ba3b025884']},
#   {'Edge': [{'ElementToConstruction': {'id': 'd5f3d477-755f-47d0-be85-b50ccc6af512',
#       'amount': 120.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '072f08b3-cb84-40e8-add0-892fd5c9529d']},
#   {'Edge': [{'ElementToConstruction': {'id': '1e34435a-cf0c-4517-9b7a-0e9f1af5e825',
#       'amount': 106.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'd6949371-1fcc-423c-8c02-def5d3718343']},
#   {'Edge': [{'ElementToConstruction': {'id': '26b8ca66-2d7d-48f1-8b13-d36aa88cdf82',
#       'amount': 153.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'ab1be1fd-8d73-4b1b-a704-d069887a66f6']},
#   {'Edge': [{'ElementToConstruction': {'id': 'd287e52d-849a-4f83-8048-5606e28f5eff',
#       'amount': 20.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '880d1a03-3234-4d3e-9870-762e4e3d1a80']},
#   {'Edge': [{'ElementToConstruction': {'id': '0e8d71b4-69e8-4f3a-93ac-d4c83a58b124',
#       'amount': 84.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '895f626d-f90a-42d9-b07a-0f99db210bd0']},
#   {'Edge': [{'ElementToConstruction': {'id': '8403e405-d164-40a3-8f41-eddcacbf5a30',
#       'amount': 9.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '3c0f02fd-004b-421f-82fa-f2ca46a34ede']},
#   {'Edge': [{'ElementToConstruction': {'id': '593766bc-ace8-42fc-adf7-bb6f5454ec84',
#       'amount': 1400.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'ee7f8686-8105-4397-8691-a0ec4b216b83']},
#   {'Edge': [{'ElementToConstruction': {'id': '05cbed5e-e759-42d2-b312-aed34f5dca8d',
#       'amount': 8839.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '11ffa15b-255c-4598-a4ef-253f667e8750']},
#   {'Edge': [{'ElementToConstruction': {'id': 'b12a15f4-8b3f-42b6-93be-48f77e328f96',
#       'amount': 2474.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'f39ec6f4-8e1a-4387-9a3d-6fca332c7598']},
#   {'Edge': [{'ElementToConstruction': {'id': 'cb76f068-a7c5-401f-b4d7-bf5edce459df',
#       'amount': 876.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '9082610f-c8e9-458f-85fe-d097ac033f76']},
#   {'Edge': [{'ElementToConstruction': {'id': 'd12bb566-f20e-4b5c-a52d-7bac6ac00d38',
#       'amount': 15.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'f83265d3-b6c1-4606-9e2c-a021d6a7cbab']},
#   {'Edge': [{'ElementToConstruction': {'id': '100adc22-e03c-4ac5-a1b3-62a74d67f5d1',
#       'amount': 14.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '470128b4-5cab-4826-bba0-c2d6827a18d5']},
#   {'Edge': [{'ElementToConstruction': {'id': 'aaaf4a7a-beb1-4edd-97c4-b1e1d6a6ccdf',
#       'amount': 64.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     '62f41343-5963-4eb1-9e10-d1ce5ecd2fe1']},
#   {'Edge': [{'ElementToConstruction': {'id': '2f84546e-bd63-4f38-8acf-d26f90dd3c74',
#       'amount': 685.0,
#       'enabled': True}},
#     '368b51f7-3ec6-4e70-903b-e92d3f062fa6',
#     'e6d0aaa8-129f-48f0-9046-adb871ab1c79']},
#   {'Node': {'Element': {'id': 'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#      'name': {'Danish': '27. TAGE', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': 'd6130e29-b46d-4624-b65e-53d0147bd6d8',
#       'amount': 250.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'c9af1796-2979-4437-b75a-449347decc3a']},
#   {'Edge': [{'ElementToConstruction': {'id': 'a9ff4f2c-9566-43a9-991f-cb3e25c68693',
#       'amount': 510.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '27780e62-bd1b-4731-9bbd-240c8b9f1f71']},
#   {'Edge': [{'ElementToConstruction': {'id': 'b944ec85-ebb9-44d1-914d-d8517247929d',
#       'amount': 60.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '43e4e897-1ed9-449d-96cf-c5c7dde840f2']},
#   {'Edge': [{'ElementToConstruction': {'id': 'ad0496a9-10bf-409e-aece-23d6333a4b0a',
#       'amount': 304.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '2f6dd348-7bfb-4a17-b645-5c839a40fcc4']},
#   {'Edge': [{'ElementToConstruction': {'id': '7e6041b2-b136-4f25-9d71-df2b0e4fffdf',
#       'amount': 56.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '0cd3b05d-9027-4e29-8da3-bdd19a0cb4b6']},
#   {'Edge': [{'ElementToConstruction': {'id': '71c5212f-aa68-4e21-a75d-e1e42800c45d',
#       'amount': 56.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '04252e9f-346d-4021-8500-8ee049bf3ad1']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c865d084-ec49-4007-9651-928b25b79f57',
#       'amount': 102.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '2aeda16a-d02e-4c16-93ad-a35624dfa8d1']},
#   {'Edge': [{'ElementToConstruction': {'id': '8ac9311f-8b77-4027-87a5-1ce030643e50',
#       'amount': 16.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '7638356e-e5d1-42c9-b71d-e7fe2cc7fd32']},
#   {'Edge': [{'ElementToConstruction': {'id': '02ab1903-4ac5-4a8c-98e4-cf8fbfee0ced',
#       'amount': 30.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '3ae04904-72d7-4f31-b418-2a50c54131b1']},
#   {'Edge': [{'ElementToConstruction': {'id': '37c61a94-2b5b-4c8a-8ea4-e219127e9a09',
#       'amount': 736.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '8b210d81-452a-4939-b996-6eb41c33861f']},
#   {'Edge': [{'ElementToConstruction': {'id': 'f1371155-5a78-4abd-826d-be2f9237f546',
#       'amount': 942.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'f85f9baa-c52e-4abe-bc80-cb3531a3b89a']},
#   {'Edge': [{'ElementToConstruction': {'id': '61e64aaa-19f2-4fb9-b2a7-e785824716e9',
#       'amount': 104.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '9e4cc165-adee-435a-9329-b786c3151d22']},
#   {'Edge': [{'ElementToConstruction': {'id': '395639cb-0ce3-4253-82f4-ea8532ee5583',
#       'amount': 70.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '965baa71-5ce3-4271-93b5-5f65ae84a932']},
#   {'Edge': [{'ElementToConstruction': {'id': '8ef73e17-af71-4e20-9809-5cbc29df9ccf',
#       'amount': 54.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '25aa0bc7-4b64-4821-af0e-c6a25e96b91f']},
#   {'Edge': [{'ElementToConstruction': {'id': '9bc2a12b-8756-4a15-8e10-a019427daa42',
#       'amount': 27.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '2f99b808-3439-4f06-9368-7bcea2a6ce58']},
#   {'Edge': [{'ElementToConstruction': {'id': '26999b75-9231-492c-82cd-6decf5d1bd29',
#       'amount': 101.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'c5c01bc5-6f74-4b50-84ae-fa5b347e2200']},
#   {'Edge': [{'ElementToConstruction': {'id': '469425ee-2b96-4ee0-9eae-ab517888fe62',
#       'amount': 103.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '6a50b79d-0d7d-4228-a8ec-27cb303079e1']},
#   {'Edge': [{'ElementToConstruction': {'id': '01609242-8c4a-41b7-ab44-48281f0adde0',
#       'amount': 5.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '56ac0072-119c-4640-ae66-4847d9aa9e92']},
#   {'Edge': [{'ElementToConstruction': {'id': '8a611ea2-a4a4-4d4b-a243-9e551d7e451f',
#       'amount': 122.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '518590d2-54bf-4fc7-afc3-6090799b5c56']},
#   {'Edge': [{'ElementToConstruction': {'id': '509d5646-27cf-45d9-99ec-4368f3df7a93',
#       'amount': 6.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '331bce64-9c8d-4f3c-80c8-15251e40fba3']},
#   {'Edge': [{'ElementToConstruction': {'id': '6e1984ec-4906-4433-8a06-27164c6ce412',
#       'amount': 1.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'f65348d8-d8ae-4cc9-a7e7-61362ecafaa1']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c737b033-fdd6-46f1-a7bf-ea022ca32753',
#       'amount': 3.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '0092b5ff-5021-42ab-a9a9-29161e77acfe']},
#   {'Edge': [{'ElementToConstruction': {'id': '9c15767d-05a0-4f71-a498-9b04b3c96e99',
#       'amount': 1154.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'dc634a5d-5850-464a-9f64-f917c1c2cce0']},
#   {'Edge': [{'ElementToConstruction': {'id': '3b9ce099-cbc1-41e7-9aea-f9552e6e1cd4',
#       'amount': 7.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '8208f314-a53f-4c10-8bd3-76bd929170bc']},
#   {'Edge': [{'ElementToConstruction': {'id': '49572e19-b657-4189-8794-0fc6834939a8',
#       'amount': 91.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     'c0e15f1e-1eb4-4c4c-9d02-03cac330f7ec']},
#   {'Edge': [{'ElementToConstruction': {'id': '4a1689b5-3e6d-4f52-b601-49d2b8d3a603',
#       'amount': 237.0,
#       'enabled': True}},
#     'b8202b3d-701c-4d1e-b5a9-949d46c1130d',
#     '679b5eb6-9c4d-49df-84ed-9b35a8f59150']},
#   {'Node': {'Element': {'id': '828ccd7e-7356-4377-9d91-f65523161277',
#      'name': {'Danish': '31. YDERVÆGGE, KOMPLETTERING',
#       'English': '',
#       'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Node': {'Element': {'id': '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#      'name': {'Danish': '43. GULVE', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}},
#   {'Edge': [{'ElementToConstruction': {'id': 'f4608734-4069-408d-a2c2-055a82bade6f',
#       'amount': 1256.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '74cb49f0-7915-490a-9cb4-ca2a1f0a970d']},
#   {'Edge': [{'ElementToConstruction': {'id': 'f72e40f5-d112-4e12-984d-1ea4f6200b1e',
#       'amount': 78.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '35c1903d-8f05-4c34-ac18-a6c2bc44a843']},
#   {'Edge': [{'ElementToConstruction': {'id': '9f59c039-d46c-4fb6-9290-2efa08b4f8ed',
#       'amount': 228.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     'a87db50b-b634-4a88-b1be-dfba3cea0242']},
#   {'Edge': [{'ElementToConstruction': {'id': '23c3d65f-899f-4d09-b184-f2d26b5dea75',
#       'amount': 52.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     'ddb0f75a-7c7c-41e4-9fc2-8580694e4b6e']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c06f5bf0-89bc-471a-91d6-40e3d297359a',
#       'amount': 103.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '35b2e798-17fe-47fa-b55e-c0d180b671f3']},
#   {'Edge': [{'ElementToConstruction': {'id': 'f6424c38-3b4e-4576-abcb-ce6e38838e46',
#       'amount': 234.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     'fe3fb0c6-d02e-4645-adc8-8ab04d56f196']},
#   {'Edge': [{'ElementToConstruction': {'id': 'cc539ee9-5308-4dbf-b5bb-7ff6553cc610',
#       'amount': 113.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '35fba129-e1d0-422c-9420-9c120b4c8dae']},
#   {'Edge': [{'ElementToConstruction': {'id': '7892ce05-b280-443d-846a-2f9eaaae1de8',
#       'amount': 156.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '317cd362-45d6-4f71-8e0c-9964f170c831']},
#   {'Edge': [{'ElementToConstruction': {'id': '6b93f30a-5404-4dd2-9460-9229b33b81c0',
#       'amount': 291.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '8db223ff-aa27-4d60-ac33-bdeea3359b56']},
#   {'Edge': [{'ElementToConstruction': {'id': '0f355267-4fa6-4d46-a582-e6da75accefc',
#       'amount': 10.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     'fc817b32-5fcd-456b-8537-44050f448861']},
#   {'Edge': [{'ElementToConstruction': {'id': 'a4e8972c-806e-47fb-b2a9-47e180f754e1',
#       'amount': 349.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '84233056-7096-4c2b-8684-e94939523ffc']},
#   {'Edge': [{'ElementToConstruction': {'id': '43e582e8-938d-4574-8dda-f2aac9c814b2',
#       'amount': 20.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '1d704e22-9313-45c5-a8da-a70210d8c41c']},
#   {'Edge': [{'ElementToConstruction': {'id': '609a73b6-51f3-4f9b-9555-a5bf0811986a',
#       'amount': 37.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '88fdffcf-287b-4ef1-a35a-c34f142c424d']},
#   {'Edge': [{'ElementToConstruction': {'id': '9428c0d7-5f0f-4ee2-b1af-72a88ded1756',
#       'amount': 603.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '108387b0-37af-4745-834e-b28957f0c9c7']},
#   {'Edge': [{'ElementToConstruction': {'id': '76d1cfa3-75d9-4003-bb55-1586aa941174',
#       'amount': 195.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '8ec76832-0efa-4c8d-aadb-1e0ee372c61c']},
#   {'Edge': [{'ElementToConstruction': {'id': 'c303c298-24d6-43bb-922a-879bfe5b3573',
#       'amount': 2520.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     '834a82b2-ad2e-461b-9521-d06af9463479']},
#   {'Edge': [{'ElementToConstruction': {'id': '56a002a4-8b60-415b-8c43-b8285c27e4eb',
#       'amount': 159.0,
#       'enabled': True}},
#     '0cfd23a8-2e55-45ad-a764-ba5cd6f6e362',
#     'c0a93a4a-ca28-4068-9f13-beb17701aea6']},
#   {'Node': {'Element': {'id': 'dfad9278-0f65-4b34-aeab-628fb69ec7b5',
#      'name': {'Danish': '45. LOFTER', 'English': '', 'German': ''},
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'enabled': True,
#      'active': True}}}],
#  [{'Node': {'Construction': {'id': 'ad379824-4121-4fe4-bcc9-370d18290b4c',
#      'name': {'Danish': '(13)1 - Terrændæk, Kælderplan',
#       'English': 'Test construction'},
#      'unit': 'M2',
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'layer': 1,
#      'locked': True}}},
#   {'Edge': [{'ConstructionToProduct': {'id': '3138dfc2-7095-4d2c-b32e-c3211354b357',
#       'amount': 0.12,
#       'unit': 'M3',
#       'lifespan': 50,
#       'demolition': False,
#       'enabled': True,
#       'delayed_start': 0}},
#     'ad379824-4121-4fe4-bcc9-370d18290b4c',
#     '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#   {'Edge': [{'ConstructionToProduct': {'id': '0c51edc0-4844-4529-a89f-b71f49dda0a7',
#       'amount': 0.3,
#       'unit': 'M3',
#       'lifespan': 50,
#       'demolition': False,
#       'enabled': True,
#       'delayed_start': 0}},
#     'ad379824-4121-4fe4-bcc9-370d18290b4c',
#     '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#   {'Node': {'Construction': {'id': 'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#      'name': {'Danish': '(13)2 - Terrændæk, Kælderplan - Vådrum',
#       'English': 'Test construction'},
#      'unit': 'M2',
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#      'layer': 1,
#      'locked': True}}},
#   {'Edge': [{'ConstructionToProduct': {'id': 'ee47616f-29f5-4bb9-af51-4bd8ce0fcdda',
#       'amount': 0.105,
#       'unit': 'M3',
#       'lifespan': 50,
#       'demolition': False,
#       'enabled': True,
#       'delayed_start': 0}},
#     'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#     '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#   {'Edge': [{'ConstructionToProduct': {'id': '4085feea-32da-4300-be54-3c4f6a3e6e48',
#       'amount': 0.3,
#       'unit': 'M3',
#       'lifespan': 50,
#       'demolition': False,
#       'enabled': True,
#       'delayed_start': 0}},
#     'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#     '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#   {'Node': {'Construction': {'id': '727a31e9-6aef-4793-b5d3-baff00f77cb9',
#      'name': {'Danish': '(13)3 - Terrændæk Stueplan',
#       'English': 'Test construction'},
#      'unit': 'M2',
#      'source': 'User',
#      'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',

#       'layers': [1]}},
#     '069983d0-d08b-405b-b816-d28ca9648956',
#     '834a82b2-ad2e-461b-9521-d06af9463479']},
#   {'Edge': [{'CategoryToConstruction': {'id': 'b6d986c3-70cc-4793-88cc-4d9b7ad1aa1c',
#       'layers': [1]}},
#     '069983d0-d08b-405b-b816-d28ca9648956',
#     'c0a93a4a-ca28-4068-9f13-beb17701aea6']}])

# %%
json_array_elements = lcabygjson.add_things_json_list(json_array_elements, lcabyg_elements[0])
json_array_constructions = lcabygjson.add_things_json_list(json_array_constructions, lcabyg_elements[1])
json_array_element_category_edges = lcabygjson.add_things_json_list(json_array_element_category_edges, lcabyg_elements[2])
json_array_constructions_extra = lcabygjson.add_things_json_list(json_array_constructions_extra, lcabyg_elements[3])

# %%
json_array_constructions
# Out:
# [{'Node': {'Construction': {'id': 'ad379824-4121-4fe4-bcc9-370d18290b4c',
#     'name': {'Danish': '(13)1 - Terrændæk, Kælderplan',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '3138dfc2-7095-4d2c-b32e-c3211354b357',
#      'amount': 0.12,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'ad379824-4121-4fe4-bcc9-370d18290b4c',
#    '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#  {'Edge': [{'ConstructionToProduct': {'id': '0c51edc0-4844-4529-a89f-b71f49dda0a7',
#      'amount': 0.3,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'ad379824-4121-4fe4-bcc9-370d18290b4c',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': 'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#     'name': {'Danish': '(13)2 - Terrændæk, Kælderplan - Vådrum',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'ee47616f-29f5-4bb9-af51-4bd8ce0fcdda',
#      'amount': 0.105,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#    '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#  {'Edge': [{'ConstructionToProduct': {'id': '4085feea-32da-4300-be54-3c4f6a3e6e48',
#      'amount': 0.3,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'b9b89dee-194a-41cd-b245-0dd3b8bdad92',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': '727a31e9-6aef-4793-b5d3-baff00f77cb9',
#     'name': {'Danish': '(13)3 - Terrændæk Stueplan',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '162f6808-6a61-4526-b742-e09cd64ee0f4',
#      'amount': 0.12,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '727a31e9-6aef-4793-b5d3-baff00f77cb9',
#    '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#  {'Edge': [{'ConstructionToProduct': {'id': '9c205dd2-ecf6-4245-950a-f3069c2b4f2f',
#      'amount': 0.3,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '727a31e9-6aef-4793-b5d3-baff00f77cb9',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': '00139490-43c6-4e16-b89c-2901b967276c',
#     'name': {'Danish': '(13)4 - Terrændæk Stueplan - Vådrum',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '9ac7a10b-12a4-496e-a485-2e120b4a38ac',
#      'amount': 0.12,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '00139490-43c6-4e16-b89c-2901b967276c',
#    '8a468320-3e31-48c3-a912-3d5cc90771b4']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'a003ba37-ff2d-46b6-9266-9454cad44eaf',
#      'amount': 0.3,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '00139490-43c6-4e16-b89c-2901b967276c',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': 'fa96455b-540d-49a4-a62c-bc75e49070e8',
#     'name': {'Danish': '(12)1 Sokkel under ydervæg',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '291c9088-8797-48ff-9c93-3281c03edf9d',
#      'amount': 0.01,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'fa96455b-540d-49a4-a62c-bc75e49070e8',
#    '28b79b9f-ee4a-4c8e-843c-8f666713aca1']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'a27896bc-a0da-4f96-ae0b-5fca762971bc',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'fa96455b-540d-49a4-a62c-bc75e49070e8',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': '087432a2-6c9a-4a4e-ae53-b516e4af640c',
#     'name': {'Danish': '(21)1 - Ydervæg, Kælder',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '8024682a-fc6f-42e2-8bfb-322994bbda53',
#      'amount': 0.01,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '087432a2-6c9a-4a4e-ae53-b516e4af640c',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': '638cdd22-1ed6-46f4-8c64-ed01e63158be',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '087432a2-6c9a-4a4e-ae53-b516e4af640c',
#    '6ab47d6b-8c6a-42fb-ae05-68ddeca7498f']},
#  {'Edge': [{'ConstructionToProduct': {'id': '68b7691f-0225-499b-aaa7-a55dd1627188',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '087432a2-6c9a-4a4e-ae53-b516e4af640c',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Node': {'Construction': {'id': 'a2d3eff5-ebd4-4216-b4ee-e69eb2b229c2',
#     'name': {'Danish': '(21)2 - Ydervæg', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'e0f8fe08-3ec4-4a79-b998-90c8a7a4d09c',
#      'amount': 0.01,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'a2d3eff5-ebd4-4216-b4ee-e69eb2b229c2',
#    '28b79b9f-ee4a-4c8e-843c-8f666713aca1']},
#  {'Edge': [{'ConstructionToProduct': {'id': '57740f2a-b946-4b32-8614-dc7ac0ed308e',
#      'amount': 0.18,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'a2d3eff5-ebd4-4216-b4ee-e69eb2b229c2',
#    '6ab47d6b-8c6a-42fb-ae05-68ddeca7498f']},
#  {'Edge': [{'ConstructionToProduct': {'id': '4d9c75b0-61cf-46bc-b0f3-57d90f58eb9a',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'a2d3eff5-ebd4-4216-b4ee-e69eb2b229c2',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Node': {'Construction': {'id': '2b4aa808-1010-4f5b-a07a-1e182661049e',
#     'name': {'Danish': '(21)3 - Kvist ydervægge',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '32a3cd6c-23b7-45a9-af7e-c6b3e5e0918d',
#      'amount': 0.006,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '2b4aa808-1010-4f5b-a07a-1e182661049e',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': '68bf21ad-361d-45bb-8627-e48c4f80a566',
#      'amount': 0.009,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    

#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8d2cdf68-758c-41eb-be00-38423304f683',
#    '6ab47d6b-8c6a-42fb-ae05-68ddeca7498f']},
#  {'Edge': [{'ConstructionToProduct': {'id': '739e7a70-62b8-483d-ac8a-72071b015804',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8d2cdf68-758c-41eb-be00-38423304f683',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Node': {'Construction': {'id': '19b6741c-a425-49c4-8369-4147aa300278',
#     'name': {'Danish': '(21)4 2', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '3466b4a1-1c32-4e1c-aac3-72b6943f4a04',
#      'amount': 0.01,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '19b6741c-a425-49c4-8369-4147aa300278',
#    '28b79b9f-ee4a-4c8e-843c-8f666713aca1']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'bdfe281a-e7e7-42a1-899e-f52956ea073c',
#      'amount': 0.15,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '19b6741c-a425-49c4-8369-4147aa300278',
#    '6ab47d6b-8c6a-42fb-ae05-68ddeca7498f']},
#  {'Edge': [{'ConstructionToProduct': {'id': '2299745c-056e-4a79-bf6f-9db8aca18ef8',
#      'amount': 0.25,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '19b6741c-a425-49c4-8369-4147aa300278',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Node': {'Construction': {'id': 'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#     'name': {'Danish': '(21)4 Let ydervæg', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '002e5339-d614-4ddb-a140-2ba3d641e9c7',
#      'amount': 0.01,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': '78966599-95a3-4137-8833-c4df8a55121e',
#      'amount': 0.013,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': '6621bf3a-b46a-4210-b943-84beb573b9cd',
#      'amount': 0.015,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'af5c50e7-dab1-4f01-b439-2a819c67bcc5',
#      'amount': 0.025,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': '8e1000bd-74c4-4a3f-bde7-1099fd85d5ad',
#      'amount': 0.095,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Edge': [{'ConstructionToProduct': {'id': '757070e2-492b-44e8-af1e-0b8f23f70ef6',
#      'amount': 0.245,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Edge': [{'ConstructionToProduct': {'id': '59350512-e995-480b-b695-b8ae8fdbc012',
#      'amount': 0.015,
#      'unit': 'KG',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c3bbab90-b3aa-4a3b-8a2e-4f4574bad435',
#    '56a43281-b3e7-459c-bdd6-fe5c949fa6f2']},
#  {'Node': {'Construction': {'id': 'a32038a5-5757-47d7-9dd2-c14db9afa1bd',
#     'name': {'Danish': 'IVP-01.N01', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 
English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'e957d54f-c5d9-4c9c-ae8b-b6ff9e801c50',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8208f314-a53f-4c10-8bd3-76bd929170bc',
#    'b8afe642-ab4f-45f0-b205-ff4a7c3e7840']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'dd992b11-446a-4d05-a337-aa7b359e1fcd',
#      'amount': 0.5,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8208f314-a53f-4c10-8bd3-76bd929170bc',
#    'd31dba83-e710-41c4-aa98-61f69598d369']},
#  {'Node': {'Construction': {'id': 'c0e15f1e-1eb4-4c4c-9d02-03cac330f7ec',
#     'name': {'Danish': 'Underkonstruktion', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '9216735b-dc29-4328-bd7e-418562c73a3b',
#      'amount': 0.025,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c0e15f1e-1eb4-4c4c-9d02-03cac330f7ec',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'dc14a4ac-2ddd-44f4-ac59-721b79e4e421',
#      'amount': 0.15,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c0e15f1e-1eb4-4c4c-9d02-03cac330f7ec',
#    '436b04f7-0a81-4f07-b6f6-e2bc3d500091']},
#  {'Edge': [{'ConstructionToProduct': {'id': '52a8361f-12b9-476f-8b65-02f81c9b48ea',
#      'amount': 0.015,
#      'unit': 'KG',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c0e15f1e-1eb4-4c4c-9d02-03cac330f7ec',
#    '56a43281-b3e7-459c-bdd6-fe5c949fa6f2']},
#  {'Node': {'Construction': {'id': '679b5eb6-9c4d-49df-84ed-9b35a8f59150',
#     'name': {'Danish': 'zink 80', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '8585261e-bcc7-4d3a-a79b-1ca98cac7ce1',
#      'amount': 0.025,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '679b5eb6-9c4d-49df-84ed-9b35a8f59150',
#    '9c9cc50d-e76a-45cf-bfd2-d9eabc26ed55']},
#  {'Edge': [{'ConstructionToProduct': {'id': 'bb965f01-4ba0-4e8f-a828-c0b36402ba92',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '679b5eb6-9c4d-49df-84ed-9b35a8f59150',
#    'd01ac82c-1522-4ed8-a1ab-299678bdf54c']},
#  {'Node': {'Construction': {'id': '74cb49f0-7915-490a-9cb4-ca2a1f0a970d',
#     'name': {'Danish': 'FP01 Trægulv 21 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '77ec0bc3-0d7d-45f1-ae17-c664309df1ff',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '74cb49f0-7915-490a-9cb4-ca2a1f0a970d',
#    'e8f5aad5-882d-4cf5-8486-f291eb27cfa6']},
#  {'Node': {'Construction': {'id': '35c1903d-8f05-4c34-ac18-a6c2bc44a843',
#     'name': {'Danish': 'FP04 Terrazzogulv 15 mm',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '3e9f33c8-11ca-431c-a239-cca015ae5175',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '35c1903d-8f05-4c34-ac18-a6c2bc44a843',
#    '8b0333cb-296b-40d4-b317-66adfbfa14be']},
#  {'Node': {'Construction': {'id': 'a87db50b-b634-4a88-b1be-dfba3cea0242',
#     'name': {'Danish': 'FP06 gulvtæppe 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'c27b00a0-6880-47b2-8f92-1542f8f0d4fa',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'a87db50b-b634-4a88-b1be-dfba3cea0242',
#    '7fb431e7-624a-4049-9089-8742844da2f2']},
#  {'Node': {'Construction': {'id': 'ddb0f75a-7c7c-41e4-9fc2-8580694e4b6e',
#     'name': {'Danish': 'FP07 Mosaik 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'cb04671c-6d6d-4475-82bc-ebeb07ed48eb',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'ddb0f75a-7c7c-41e4-9fc2-8580694e4b6e',
#    '0ea3738f-600d-45be-bb2d-62a20dc51a4a']},
#  {'Node': {'Construction': {'id': '35b2e798-17fe-47fa-b55e-c0d180b671f3',
#     'name': {'Danish': 'FP08 Mosaik 20 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '8caf3d84-1bb8-48ef-8264-06eaf3185a2b',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '35b2e798-17fe-47fa-b55e-c0d180b671f3',
#    '45b5cc79-b927-4ee7-a326-02fdb9f871f9']},
#  {'Node': {'Construction': {'id': 'fe3fb0c6-d02e-4645-adc8-8ab04d56f196',
#     'name': {'Danish': 'FP09 Trægulv 21 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'cbd2345c-c1b1-4faa-88e5-9f3a04755711',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'fe3fb0c6-d02e-4645-adc8-8ab04d56f196',
#    '49362f90-149b-4ec2-9c54-6f74c4e046ef']},
#  {'Node': {'Construction': {'id': '35fba129-e1d0-422c-9420-9c120b4c8dae',
#     'name': {'Danish': 'FP10 gulvtæppe 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '60732231-0396-4d72-85e7-62d1165e0d52',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '35fba129-e1d0-422c-9420-9c120b4c8dae',
#    'd3ab9431-80fe-47dc-9978-b779b5d01517']},
#  {'Node': {'Construction': {'id': '317cd362-45d6-4f71-8e0c-9964f170c831',
#     'name': {'Danish': 'FP11 gulvtæppe 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'cb37a599-cb25-4b47-a9af-3bd907c0f331',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '317cd362-45d6-4f71-8e0c-9964f170c831',
#    '16e6d002-ab98-4c91-a915-4ce2fd0226d1']},
#  {'Node': {'Construction': {'id': '8db223ff-aa27-4d60-ac33-bdeea3359b56',
#     'name': {'Danish': 'FP12 gulvtæppe 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '59489538-4a48-43de-bcff-37f6f140cea2',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8db223ff-aa27-4d60-ac33-bdeea3359b56',
#    '274fd34d-de30-47bc-bc32-a26728823a33']},
#  {'Node': {'Construction': {'id': 'fc817b32-5fcd-456b-8537-44050f448861',
#     'name': {'Danish': 'FP14 Massagolv 25 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '2f9aa082-9530-4e3a-8dd8-1c355c3ec66b',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'fc817b32-5fcd-456b-8537-44050f448861',
#    'e4762931-1b74-4f55-831e-59244d1429cb']},
#  {'Node': {'Construction': {'id': '84233056-7096-4c2b-8684-e94939523ffc',
#     'name': {'Danish': 'FP16 Massagolv 20 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '5f1585cb-b7ee-4e06-b598-bb4a00fd9c4f',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '84233056-7096-4c2b-8684-e94939523ffc',
#    '27b22294-0aeb-420b-9418-5a10c798d5cd']},
#  {'Node': {'Construction': {'id': '1d704e22-9313-45c5-a8da-a70210d8c41c',
#     'name': {'Danish': 'FP17 gulvtæppe 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '39e9feeb-2a00-4028-96cc-be95518cbf81',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '1d704e22-9313-45c5-a8da-a70210d8c41c',
#    '399403f2-78ae-40f4-af46-6b085e538a1e']},
#  {'Node': {'Construction': {'id': '88fdffcf-287b-4ef1-a35a-c34f142c424d',
#     'name': {'Danish': 'FP18 Mosaik 15 mm', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '5829b84f-e3f8-4242-99ed-8b782736070f',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '88fdffcf-287b-4ef1-a35a-c34f142c424d',
#    '729483b5-a429-4e0f-90de-55429dff6ef9']},
#  {'Node': {'Construction': {'id': '108387b0-37af-4745-834e-b28957f0c9c7',
#     'name': {'Danish': 'Gulv bad Hotelværelser',
#      'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': '91748e99-aea0-4f9e-bb2a-f68f32126dff',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '108387b0-37af-4745-834e-b28957f0c9c7',
#    '21f3dae4-3b11-4adf-82a3-5b396b3ead88']},
#  {'Node': {'Construction': {'id': '8ec76832-0efa-4c8d-aadb-1e0ee372c61c',
#     'name': {'Danish': 'Gulv gang', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'd5e7847c-ec55-4801-aed8-ef4c028522cd',
#      'amount': 0.015,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '8ec76832-0efa-4c8d-aadb-1e0ee372c61c',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Node': {'Construction': {'id': '834a82b2-ad2e-461b-9521-d06af9463479',
#     'name': {'Danish': 'Gulv Hotelværelser', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'a4a0effc-5209-4bd4-bc42-8e01bb37d11e',
#      'amount': 0.015,
#      'unit': 'M3',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    '834a82b2-ad2e-461b-9521-d06af9463479',
#    'b120fb03-7bb3-4be9-aff1-c37771850179']},
#  {'Node': {'Construction': {'id': 'c0a93a4a-ca28-4068-9f13-beb17701aea6',
#     'name': {'Danish': 'Gulvfliser', 'English': 'Test construction'},
#     'unit': 'M2',
#     'source': 'User',
#     'comment': 'Created by IfcJsonLcabygParser. https://github.com/Curiosit/IfcJsonLcabygParser',
#     'layer': 1,
#     'locked': True}}},
#  {'Edge': [{'ConstructionToProduct': {'id': 'a460fe59-3d98-498f-b094-3d1f433e442c',
#      'amount': 1.0,
#      'unit': 'M2',
#      'lifespan': 50,
#      'demolition': False,
#      'enabled': True,
#      'delayed_start': 0}},
#    'c0a93a4a-ca28-4068-9f13-beb17701aea6',
#    '21f3dae4-3b11-4adf-82a3-5b396b3ead88']}]

# %%
try:
  with open('dk-lcabyg_json/elements.json', 'w') as outfile:
        json.dump(json_array_elements, outfile,indent=4)
  with open('dk-lcabyg_json/constructions.json', 'w') as outfile:
        json.dump(json_array_constructions, outfile,indent=4)
  with open('dk-lcabyg_json/element_category_edges.json', 'w') as outfile:
        json.dump(json_array_element_category_edges, outfile,indent=4)
  with open('dk-lcabyg_json/constructions_extra.json', 'w') as outfile:
        json.dump(json_array_constructions_extra, outfile,indent=4)
  print("Files exported successfully")
except:
  print("An exception occurred")
# Out:
# Files exported successfully
